# %%
import torch
from transformers import BertForMaskedLM
from datasets import load_from_disk
import numpy as np
import os
import numpy as np
import matplotlib.pyplot as plt
from geneformer import TranscriptomeTokenizer
import pickle
import os
import anndata as ad
import scanpy as sc
import loompy
from collections import defaultdict

# %%
# Finding mappings from tokenizer gene to token id so for calculating attention weights

# Initialize the tokenizer
tokenizer = TranscriptomeTokenizer({'stimulation': 'stimulation'}, model_input_size=2048)


token_dict = tokenizer.gene_token_dict
print(f"Token dictionary contains {len(token_dict)} entries")

print("\nSample of token dictionary (first 10 entries):")
sample_items = list(token_dict.items())[:10]
for gene, token_id in sample_items:
    print(f"Gene: {gene}, Token ID: {token_id}")

# Create reverse mapping (token ID to gene)
token_to_gene = {}
for gene, token_id in token_dict.items():
    token_to_gene[token_id] = gene

# Print sample of reverse mapping
print("\nSample of token_to_gene mapping (first 10 entries):")
sample_items = list(token_to_gene.items())[:10]
for token_id, gene in sample_items:
    print(f"Token ID: {token_id}, Gene: {gene}")
# Out:
# Token dictionary contains 20275 entries
#
# Sample of token dictionary (first 10 entries):
# Gene: <pad>, Token ID: 0
# Gene: <mask>, Token ID: 1
# Gene: <cls>, Token ID: 2
# Gene: <eos>, Token ID: 3
# Gene: ENSG00000000003, Token ID: 4
# Gene: ENSG00000000005, Token ID: 5
# Gene: ENSG00000000419, Token ID: 6
# Gene: ENSG00000000457, Token ID: 7
# Gene: ENSG00000000460, Token ID: 8
# Gene: ENSG00000000938, Token ID: 9
#
# Sample of token_to_gene mapping (first 10 entries):
# Token ID: 0, Gene: <pad>
# Token ID: 1, Gene: <mask>
# Token ID: 2, Gene: <cls>
# Token ID: 3, Gene: <eos>
# Token ID: 4, Gene: ENSG00000000003
# Token ID: 5, Gene: ENSG00000000005
# Token ID: 6, Gene: ENSG00000000419
# Token ID: 7, Gene: ENSG00000000457
# Token ID: 8, Gene: ENSG00000000460
# Token ID: 9, Gene: ENSG00000000938

# %%
# Saving cell States so we can map for attention weights
ds = loompy.connect("/u/home/r/ramadas/geneformer_tokenized_data/labeled_t_cell_data.loom")

# Extract the stimulation states for all cells
stimulation_states = ds.ca.stimulation
print(f"Extracted {len(stimulation_states)} cell classifications")
print(f"Sample values: {stimulation_states[:10]}")

# Convert to binary labels (assuming 'act' = 1, 'rest' = 0)
cell_labels = np.array([1 if state == 'act' else 0 for state in stimulation_states])
print(f"Sample Values: {cell_labels[:10]}")
# Out:
# Extracted 47726 cell classifications
# Sample values: [np.str_('rest') np.str_('act') np.str_('rest') np.str_('rest')
#  np.str_('rest') np.str_('act') np.str_('rest') np.str_('rest')
#  np.str_('act') np.str_('rest')]
# Sample Values: [0 1 0 0 0 1 0 0 1 0]

# %%
# Directory paths
model_directory = "/u/scratch/r/ramadas/geneformer_output/t80-20/250330223625/250330_geneformer_cellClassifier_cm_classifier_test/ksplit1/"
input_data_file = "/u/home/r/ramadas/geneformer_tokenized_data/Q_data_.dataset"
output_directory = "/u/scratch/r/ramadas/geneformer_output/t80-20/250330223625/attention_weights"
os.makedirs(output_directory, exist_ok=True)

# Load with output attentins set to true
model = BertForMaskedLM.from_pretrained(
    model_directory,
    output_hidden_states=True,
    output_attentions=True
)
model.eval()
model.to("cuda")
# load and select number of cells we want to evaluate 
dataset = load_from_disk(input_data_file)

max_cells = 10
cell_attention_data = []
layer_to_extract = 5  

# Specify which layer's attention you want
for i in range(min(max_cells,len(dataset))):
    example_cell = dataset.select([i])
    example_cell.set_format(type="torch")
    input_data = example_cell["input_ids"]

    cell_label = "Proliferating" if cell_labels[i] == 1 else "Quiescent"
    # Not updating model just evaluating 
    with torch.no_grad():
        outputs = model(input_ids=input_data.to("cuda"))
        print(f"input_data shape: {input_data.shape}")
        print(f"First few token IDs: {input_data[:10]}")
        
        if hasattr(outputs, 'attentions') and outputs.attentions is not None:
            # Extract the attention weights from the specified layer
            attn = outputs.attentions[layer_to_extract]

            # Map token IDs to gene names
            token_ids = input_data[0].cpu().numpy()
            gene_names = [token_to_gene.get(int(token_id), f"Unknown_{token_id}") for token_id in token_ids]
            print(f"First genes: {gene_names[:10]}")
            
            cell_attention_data.append({
                'cell_idx': i,
                'label': cell_labels[i],
                'label_name': cell_label,
                'token_ids': token_ids,
                'gene_names': gene_names,
                'attention': attn.cpu().numpy()
            })
            
            print(f"Processed cell {i}, Label: {cell_label}") 

torch.save(cell_attention_data, output_file)
print(f"Saved attention weights to {output_file}")
# Out:
# Some weights of BertForMaskedLM were not initialized from the model checkpoint at /u/scratch/r/ramadas/geneformer_output/t80-20/250330223625/250330_geneformer_cellClassifier_cm_classifier_test/ksplit1/ and are newly initialized: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# input_data shape: torch.Size([1, 2048])
# First few token IDs: tensor([[    2, 11305,  3104,  ...,  6528, 11543,     3]])
# First genes: ['<cls>', 'ENSG00000164972', 'ENSG00000105519', 'ENSG00000087086', 'ENSG00000160188', 'ENSG00000188010', 'ENSG00000197956', 'ENSG00000177989', 'ENSG00000187608', 'ENSG00000106211']
# Processed cell 0, Label: Quiescent
# input_data shape: torch.Size([1, 2048])
# ...

# %%
# Dictionary to store layer-wise embeddings
all_embeddings = {}

# Loop through cells
for i in range(min(max_cells, len(dataset))):
    example_cell = dataset.select([i])
    example_cell.set_format(type="torch")
    input_data = example_cell["input_ids"]
    cell_label = "Proliferating" if cell_labels[i] == 1 else "Quiescent"
    
    with torch.no_grad():
        outputs = model(input_ids=input_data.to("cuda"))
        
        # Initialize dict for this cell
        all_embeddings[i] = {
            'label': cell_labels[i],
            'label_name': cell_label,
            'layer_embeddings': []
        }
        
        # Store embeddings from each layer
        for layer_idx, layer_output in enumerate(outputs.hidden_states):
            # For cell-level embedding: mean pooling across all genes
            cell_embedding = layer_output[0].mean(dim=0).cpu().numpy()
            # Or if you want gene-level embeddings:
            # gene_embeddings = layer_output[0].cpu().numpy()
            
            all_embeddings[i]['layer_embeddings'].append({
                'layer': layer_idx,
                'embedding': cell_embedding
            })
            print(all_embeddings[i])
# Out:
# {'label': np.int64(0), 'label_name': 'Quiescent', 'layer_embeddings': [{'layer': 0, 'embedding': array([-1.22158617e-01,  9.56932157e-02,  3.26767787e-02,  1.56196877e-02,
#        -5.38583547e-02, -2.82560885e-02, -1.11715067e-02, -3.41173261e-02,
#         2.86254007e-02, -1.12081945e-01,  1.01096496e-01,  9.03361849e-03,
#        -8.10871720e-02,  5.96231744e-02, -3.93323191e-02,  4.80151922e-02,
#         2.22000061e-03,  2.78197713e-02,  1.82852447e-02, -1.01181611e-01,
#        -2.75860447e-02, -3.88854742e-02,  1.38360839e-02, -3.99082676e-02,
#        -1.95343383e-02,  9.97650251e-03,  3.31336781e-02,  5.57877719e-02,
#         3.77027318e-02,  8.30968171e-02, -3.01293973e-02, -2.84758564e-02,
#         7.82256201e-03, -2.09227018e-02,  8.96390229e-02,  1.40317068e-01,
#        -9.54959169e-03,  4.01222110e-02, -2.37472281e-02, -3.08620511e-03,
#         3.38734835e-02,  2.25315765e-02, -6.40552714e-02,  7.36126229e-02,
# ...

# %%
# Load the saved attention weights
attention_weights_path = "/u/scratch/r/ramadas/geneformer_output/t80-20/250330223625/attention_weights/attention_weights_layer_5.pt"
attention_weights = torch.load(attention_weights_path, weights_only=False)


print(f"Number of cells in the saved data: {len(attention_weights)}")
print(f"Shape of first cell's attention weights: {attention_weights[0]['attention'].shape}")

# First cell attention data
first_cell_attn = attention_weights[0]['attention']
first_head = first_cell_attn[0, 0]  # [batch_size=0, head_idx=0]
sample_size = 10

print("\nSample of attention weights from first cell, first head (10x10):")
for i in range(sample_size):
    row = first_head[i, :sample_size]
    print([f"{val:.4f}" for val in row])

# Visualize attention pattern for a cell
plt.figure(figsize=(10, 8))
plt.imshow(first_head[:20, :20], cmap='viridis')
plt.colorbar()
plt.title("Attention Weights (First 20x20 tokens)")
plt.xlabel("Token Position (Target)")
plt.ylabel("Token Position (Source)")
plt.savefig("/u/scratch/r/ramadas/geneformer_output/t80-20/250330223625/attention_weights/attention_heatmap.png")
print("\nSaved visualization to attention_heatmap.png")
# Out:
# Number of cells in the saved data: 10
# Shape of first cell's attention weights: (1, 4, 2048, 2048)
#
# Sample of attention weights from first cell, first head (10x10):
# ['0.0007', '0.0000', '0.0002', '0.0000', '0.0000', '0.0000', '0.0009', '0.0000', '0.0000', '0.0000']
# ['0.0007', '0.0001', '0.0003', '0.0000', '0.0000', '0.0000', '0.0011', '0.0000', '0.0000', '0.0000']
# ['0.0005', '0.0000', '0.0002', '0.0000', '0.0000', '0.0000', '0.0008', '0.0000', '0.0000', '0.0000']
# ['0.0003', '0.0000', '0.0001', '0.0000', '0.0000', '0.0000', '0.0005', '0.0000', '0.0000', '0.0000']
# ['0.0004', '0.0000', '0.0001', '0.0000', '0.0000', '0.0000', '0.0005', '0.0000', '0.0000', '0.0000']
# ['0.0005', '0.0000', '0.0001', '0.0000', '0.0000', '0.0000', '0.0006', '0.0000', '0.0000', '0.0000']
# ['0.0006', '0.0000', '0.0002', '0.0000', '0.0000', '0.0000', '0.0011', '0.0000', '0.0000', '0.0000']
# ['0.0004', '0.0000', '0.0002', '0.0000', '0.0000', '0.0000', '0.0008', '0.0000', '0.0000', '0.0000']
# ...

# %%
# Take Attention Weight Matrix and sum down gene returning genes recieving greatest attention per cell

# Two ways to do it summing and also cls(which is used for classification)
def rank_genes_by_attention(cell_attention_data, method="sum", num_top_genes=50):
    cell_rankings = []
    
    # Saving by gene type so we can later generalize based on these
    quiescent_genes = defaultdict(list)
    proliferating_genes = defaultdict(list)
    all_genes = defaultdict(list)
    
    for index,cell_data in enumerate(cell_attention_data):
            gene_names = cell_data['gene_names']
            attention = cell_data['attention'][0]  # First batch
            label = cell_data['label_name']
            print(f'Cell {index}, {label}')

            avg_attention = np.mean(attention, axis = 0)

            # Calculate gene importance
            if method == "cls":
                # CLS token is at position 0 - how much it attends to each gene
                gene_importance = avg_attention[0]
            else: 
                # Sum attention down columns (how much attention each gene receives)
                gene_importance = np.sum(avg_attention, axis=0)

            if label == "Quiescent":
                gene_dict = quiescent_genes
            elif label == "Proliferating":
                gene_dict = proliferating_genes

            cell_gene_scores = {}

            # Now map these summed weights to the gene name by indexing
            for i, gene in enumerate(gene_names):
                score = float(gene_importance[i])
                cell_gene_scores[gene] = score


                #Now aggregating to those cell dictionaries 
                gene_dict[gene].append(score)
                all_genes[gene].append(score)

            # Ranking genes within each cell by attention weights
            ranked_genes = sorted(cell_gene_scores.items(), key=lambda x: x[1], reverse=True)
            for gene, score in ranked_genes[:10]:
                print(f'Gene: {gene}, Score: {score}')

            # Saving in Cell Rankings so we can compare across them 
            cell_df = pd.DataFrame(ranked_genes[:num_top_genes], columns=['Gene', 'Attention Score'])
            cell_rankings.append({
                'cell_id': index,
                'label': label,
                'rankings': cell_df,
                'top_genes': [gene for gene, _ in ranked_genes[:10]]  # Store top 10 genes for quick comparison
            })

                
                

    
run = rank_genes_by_attention(cell_attention_data, method="sum")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 63
#      51             cell_df = pd.DataFrame(ranked_genes[:num_top_genes], columns=['Gene', 'Attention Score'])
#      52             cell_rankings.append({
#      53                 'cell_id': index,
#      54                 'label': label,
#      55                 'rankings': cell_df,
#      56                 'top_genes': [gene for gene, _ in ranked_genes[:10]]  # Store top 10 genes for quick comparison
#      57             })
# ---> 63 run = rank_genes_by_attention(cell_attention_data, method="sum")
#
# Cell In[22], line 8, in rank_genes_by_attention(cell_attention_data, method, num_top_genes)
#       5 cell_rankings = []
#       7 # Saving by gene type so we can later generalize based on these
# ----> 8 quiescent_genes = defaultdict(list)
#       9 proliferating_genes = defaultdict(list)
# ...
